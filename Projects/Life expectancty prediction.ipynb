# %% [markdown]
# # Python Mini Project
#
# **Name: Sneha Gupta <br>
# RegNo: 21112341 <br>
# Class: 3BScEA**
# ****

# %% [markdown]
# ### **Objective:** <br>
# * The main objective is to perform Knowledge Discovery in Databases(KDD) to analyze the data, build the model and perform Exploratory Data Analysis(EDA).
# * Import and merge three datasets to perform analysis from the merged dataset.
# * Clean the full dataset and tranform the data using Label Encoders.
# * Identify patterns in the data using EDA.
# * Perform Linear Regression to predict Life expectabcy of countries.

# %% [markdown]
# ### **Problem Definition:** <br>
# * Combine three cross-sectional datasets from UNDP Website : Gross Development Index(GDI), Gender Inequality Index (GII), Human Development Income(HDI) of 2020.
# * The above datasets includes various macro economics variables like Human Development, Life expectancy, Maternal Mortality Ration, Years of Schooling, Gross national Income etc.
# * We are trying to predict Life expectancy of all the countries in the world using the above mentioned macro economic indicators.
# * Analyze the impact of various economic indicators on life expectancy and then predicting life expectancy of countries using user input.

# %% [markdown]
# ### **Data link:** <br>
# [Datasets](https://hdr.undp.org/data-center/documentation-and-downloads)

# %% [markdown]
# ### **KDD Process:**
# ![The-Steps-of-a-KDD-process.png](attachment:The-Steps-of-a-KDD-process.png)

# %% [markdown]
# ### **Methodology:** <br>
# **1. Data selection** <br>
# a. Import three individual datasets from the above website using `pandas`. <br>
# b. Merging the datasets using `merge`.<br>
# c. Displaying all the features using `tabulate`.<br>
#
# **2. Data cleaning and pre processing** <br>
# a. Clean the dataset by dropping columns and rows, adding column headers, removing null values. <br>
# b. Check for duplicate columns using `user defined function` and `for loop` and dropping them. <br>
# c. Storing the name of new column names in a list sing user defined function. <br>
# d. Replacing dot values with NaN using `replace`. <br>
# e. Droppng null values. <br>
# f. Converting data type of all the columns using for loop. <br>
#
# **3. Data Transformation** <br>
# a. Transforming columns using `label encoding`, We can't transform many columns as they are macro economic indicators and exact value is needed for EDA. <br>
# b. Transforming human development and countries after performing EDA for regression. <br>
#
# **4. Data mining** <br>
# a. Made a new dataframe using `append` as a subset of the final dataframe. <br>
# b. This dataset includes the countries having high,average and low life expectancy to find new patterns in the data. <br>
# c. It helped to find that in which areas should low and average life expectancy shouuld focus on to achieve high life expectancy. <br>
#
# **5. Interpretation** <br>
# a. Performing EDA using `pandas`,`matplot` and `seaborn` libraries. <br>
# b. This helps to understand and gain inferences from the dataset.
# c. EDA is done in two parts.
#
# **6. Model testing** <br>
# a. Slpitting the data into training and testing. <br>
# b. Perforimg linear regression to get the r score to check the accuracy of the model.<br>
# c. Predicting life expectancy by taking user input using user defined function.

# %% [markdown]
# ### **Observations:** <br>
# #### **EDA PART 1**
#
# * The mean life expectancy of all the countries in the world is 71 years.
# * There are four categories of Human Development.: Very High, High, Medium and Low. Most of countries in the world have high human development followed by countries with High, Medium and Low Human Development.
# * The Gross National Income(GNI) of High Income countries are between 12696-45000. The mean income of the high income country is 30,000.
# * The Gross National Income(GNI) of Low Income countries are between 750-1046.The mean income of the Low income country is 770.
# * The Gross National Income(GNI) of Lower Middle countries are between 1600-3400. The mean income of the Lower Middle country is 2300.
# * The Gross National Income(GNI) of Upper Middle countries are between 4096-10000.The mean income of the Upper Middle country is 8000.
# *  Among the High Income countries, Singapore has the highest HDI(Human Development Index). We can infer that Singapore has the best healthcare,knowledge and standard of living out of all the countries in th World. It is one of the highest income countries.
# * Singapore, Qatar, Luxembourg, Ireland and Switzerland are the top 5 countries having highest GNI. It means that these countries have better macro - economic indicators like Literacy Ratio, Heathcare, Education, Safe drinking water etc. and these are one of the best developed countries in the world.
# * The countries that are highly developed have better life expectancy rate followed by countries with High, Medium and Low development.
# * The countries that are highly developed have better Human Developmet Index followed by countries with High, Medium and Low development.
# * As the life expectancy and HDI of Highly developed countries was the highest, their Gross National income is also the highest followed by countries with High, Medium and Low development.
# * The Gross national income(GNI) of men is greater than the GNI of women. This has mainly happened due to lack of schooling and gender inequality.
# *  There is a negative relationship between MMR(Maternal Mortality Ratio) and Life expectancy. The number of deaths due to pregnancy-related causes per 100,000 live births leads to decrease in life expectancy.
# * There is a negative relationship between ABR(Adoslescent Birth Rate) and Schoolig. We can infer that as the education qualification increases, people realize the problems associated with increasing population and hence reduces the adolescent birth rate( women giving birth at the age of 15-19 years per 1,000 women in that age group). Hence, they might also wish to adopt 'One Child Policy'.
# * There is a positive relationship between Schooling and Life expectancy. As the schooling years increase, people get knowledge about better way of living a healthy life and hence, life_exp increases.
#
# #### **EDA PART 2**
# The new df is arranged according to top 5 countries that have highest life expectancy,bottom 5 countries that have lowest life expectancy and 5 countries that have average life expectancy. The following inferences can be made: <br>
# 1. **HDI** <br>
# a.The HDI(Human Development Index) of countries with high life expectancy is greater. <br>
# b.Switzerland has the highest HDI and Chad has the lowest HDI. <br>
#
# 2. **Life expectancy** <br>
# a.There is not much difference between the life expectancy of males and females.<br>
# b.Australia has the highest number of schooling years that displays that they have ustilized resources for education. Greater the education, Greater the Human development index and hence, Greater the life expectancy. <br>
# c.Chad has the lowest life expectancy. <br>
#
# 3. **Schooling** <br>
# a.There is not much difference between the Schooling of males and females. <br>
# b.Australia has the highest Schooling and South Sudan has the lowest Schooling. <br>
#
# 4. **Gross National income** <br>
# a.The Gross National income of Switzerland is the highest and South Sudan has the lowest GNI. <br>
# b.There is not much difference between the Gross national income of males and females. <br>
#
# 5. **Human Development** <br>
# a.Switzerland has the highest Human devlopment and Chad has the lowest Human development. <br>
#
# 6. **Gender Inequality Index** <br>
# a.The Gender Inequality Rank of countries with low life expectancy is greater.This shows that gender inequality affects life expectancy. <br>
# b.Switzerland has the lowest GI and Central African Republic has the highest GI. <br>
#
# 7. **Maternal Mortality Ratio** <br>
# a.Maternal Mortality Ratio of countries with low life expectancy is greater while that of higher life expectancy is negligible. <br>
# b. Australia, Japan, Switzerland, Malta has the lowest MMR and Chad,South Sudan has the highest MMR. <br>
#
# 8. **Adolescent Birth Rate** <br>
# a.Adolescent Birth Rate of countries with low life expectancy is greater while that of higher life expectancy is negligible. <br>
# b.Japan, Switzerland,Korea have lowest ABR and Central African republic has the highest ABR. <br>
#
# 9. **Share of seats in parliament** <br>
# a.The share of seats in parliament of a country called Tonga is 0. <br>
# b.There is not much correlation between the life expectancy and share of seats in parliament. <br>
# c.Switzerland has the highest share of seats in parliament and Nigeria has the lowest.<br>
#
# 10. **Population** <br>
# a.Australia, Ukraine has the highest population and Chad has the lowest.<br>
#
# 11. **Labor Force** <br>
# a. Labor force of males is greater than Labor force of females. <br>
# b. Central African republic has the highest Labor Force and Tajikistan has the lowest.<br>

# %% [markdown]
# **Results:** <br>
# * HDI, Schooling, Gross National Income, Human Development, Gender Inequality, Maternal mortality Ratio, Adolescent Birth Rate, Population are the eight variables out of all the variables that have highest impact on Life expectancy. <br>
# * Switzerland has the highest value for almost all the indicators and that is why it is under the top 5 countries with highest life expectency in the world. This is because of the low fertility rate, malnutrition, obesity, and access to clean drinking water and fresh fruits throughout the country.<br>
# * Japan has the highest life expectancy rate of 84 years due to low rate of obesity, low consumption of red meat, and high consumption of fish and plant foods such as soybeans and tea.<br>
# * Japan, Switzerland, Australia, Korea and Malta are the countries having highest life expectancy in the world.<br>
# * Chad has the lowest life expectancy value for almost all the indicators of 50 years due to poverty, lack of doctors, intercommunal violence.<br>
# * South Sudan, Chad, Nigeria, Lesotho, Central African Republic are the countries having lowest life expectancy in the world.<br>
# * The Gross national income(GNI) of men is greater than the GNI of women. This has mainly happened due to lack of schooling and gender inequality.<br>
# * The number of deaths due to pregnancy-related causes per 100,000 live births leads to decrease in life expectancy.<br>
# * We can infer that as the education qualification increases, people realize the problems associated with increasing population and hence reduces the adolescent birth rate. <br>
# * There is not much difference between the life expectancy, schooling and gross national income of males and females.<br>
# * As gender inequality increases in the world, life expectancy decreases.<br>
# * The share of seats in parliament of a country called Tonga is 0.<br>
# * Labor force of males is greater than Labor force of females.<br>
# * The countries with low life expectancy should work on Gender Inequality, Schooling, Human development Index, Maternal mortality ratio, adolescent birth rate in order to increase life expectancy.

# %% [markdown]
# **Learnings** <br>
# * This project helped me to work on various macro economic indicator datasets and gain inferences from them.
# * It helped to study about life expectancy and the how it is impacted by a lot of variables.
# * Out of all the countries in the world, it is evident that human development is necessary for having high life expectancy.
# * I got more familiar with python plotting libraries.

# %% [markdown]
# **References:** <br>
# * Naived sir and Krish Agarwal(3 BScDS) for debugging of errors.
# * Stack overflow
# * Geeks for Geeks
# * Documentation of libraries
# * Towards data science

# %%
#Importing necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate
import numpy as np
from statistics import mean
import pickle
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # `DATA SELECTION`

# %% [markdown]
# ## Importing df1

# %%
df1 = pd.read_excel("C:\\Users\\Lenovo\\Downloads\\HDR21-22_Statistical_Annex_HDI_Table.xlsx",index_col=False)

# %%
df1.head()
# Out:
#     Back Table 1. Human Development Index and its components   \
# 0    NaN                                                NaN
# 1    NaN                                                NaN
# 2    NaN                                                NaN
# 3  S.NO.                                            Country
# 4    NaN                                                NaN
#
#                        Unnamed: 2  Unnamed: 3                Unnamed: 4  \
# 0                             NaN         NaN                       NaN
# 1                             NaN         NaN                      SDG3
# 2                             NaN         NaN                       NaN
# 3  Human Development Index (HDI)          NaN  Life expectancy at birth
# 4                           Value         NaN                   (years)
#
#   Unnamed: 5                   Unnamed: 6 Unnamed: 7               Unnamed: 8  \
# 0        NaN                          NaN        NaN                      NaN
# ...

# %% [markdown]
# ### Dropping  columns and rows

# %%
#blank columns
df1 = df1.drop(["Unnamed: 3","Unnamed: 5","Unnamed: 7","Unnamed: 9","Unnamed: 11","Unnamed: 13","Unnamed: 15",
                "Unnamed: 16","Unnamed: 17","Unnamed: 18","Unnamed: 19","Unnamed: 20","Unnamed: 21","Unnamed: 22",
                "Unnamed: 23","Unnamed: 24","Unnamed: 25","Unnamed: 26"], axis = 1)

# %%
#miscellaneous rows
df1=df1.drop(df1.index[[0,1,2,3,4,5,6]])

# %% [markdown]
# ### Column headers

# %%
# Adding column headers
df1.columns = ['S.NO.','Country','HDI',"Life expectancy",'Expected years of schooling','Mean years of schooling',
               'GNI per capita','GNI rank minus HDI rank','HDI rank_df1']

# %% [markdown]
# ### NaN values

# %%
#Checking for null values
df1.isnull().sum()
# Out:
# S.NO.                          8
# Country                        0
# HDI                            4
# Life expectancy                4
# Expected years of schooling    4
# Mean years of schooling        4
# GNI per capita                 4
# GNI rank minus HDI rank        4
# HDI rank_df1                   4
# dtype: int64

# %%
#Dropping NA values
df1 = df1.dropna()

# %% [markdown]
# ### Reset index

# %%
df1.reset_index(inplace = True, drop = True)

# %% [markdown]
# ### Setting the levels by creating a new column called "Human_Development"

# %%
df1['Human_Development'] = 0

# %%
df1["Human_Development"].loc[0:66] = "Very High"
df1["Human_Development"].loc[67:115] = "High"
df1["Human_Development"].loc[116:159] = "Medium"
df1["Human_Development"].loc[160:len(df1)-1] = "Low"
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df1
# Out:
#     S.NO.                   Country    HDI Life expectancy  \
# 0       1               Switzerland  0.962         83.9872
# 1       2                    Norway  0.961         83.2339
# 2       3                   Iceland  0.959         82.6782
# 3       4    Hong Kong, China (SAR)  0.952         85.4734
# 4       5                 Australia  0.951         84.5265
# ..    ...                       ...    ...             ...
# 186   187                   Burundi  0.426         61.6627
# 187   188  Central African Republic  0.404         53.8947
# 188   189                     Niger    0.4         61.5763
# 189   190                      Chad  0.394         52.5254
# 190   191               South Sudan  0.385         54.9752
#
#     Expected years of schooling Mean years of schooling GNI per capita  \
# 0                     16.500299                13.85966    66933.00454
# 1                       18.1852                13.00363    64660.10622
# ...

# %% [markdown]
# ## Importing DF2

# %%
df2 =  pd.read_excel("C:\\Users\\Lenovo\\Downloads\\HDR21-22_Statistical_Annex_GII_Table.xlsx")

# %%
df2.head()
# Out:
#        Back Table 5. Gender Inequality Index               Unnamed: 2  \
# 0       NaN                              NaN                      NaN
# 1       NaN                              NaN                      NaN
# 2       NaN                              NaN  Gender Inequality Index
# 3       NaN                              NaN                    Value
# 4  HDI rank                          Country                      NaN
#
#    Unnamed: 3 Unnamed: 4  Unnamed: 5                        Unnamed: 6  \
# 0         NaN        NaN         NaN                               NaN
# 1         NaN        NaN         NaN                            SDG3.1
# 2         NaN        NaN         NaN          Maternal mortality ratio
# 3         NaN       Rank         NaN  (deaths per 100,000 live births)
# 4         NaN        NaN         NaN                               NaN
#
#   Unnamed: 7                           Unnamed: 8  Unnamed: 9  \
# ...

# %% [markdown]
# ### Dropping columns and rows

# %%
#Dropping blank columns
df2 = df2.drop(["Unnamed: 3","Unnamed: 5","Unnamed: 7","Unnamed: 9","Unnamed: 11","Unnamed: 13","Unnamed: 15",
                "Unnamed: 17","Unnamed: 19"], axis = 1)

# %%
#Dropping miscellaneous rows
df2=df2.drop(df2.index[[0,1]])

# %% [markdown]
# ### Column headers

# %%
# Adding column headers
df2.columns = ["HDI_Rank_df2","Country",'Gender Inequality Index_Value_df2',"Gender Inequality Index_Rank",
               'Maternal mortality ratio','Adolescent birth rate',"Share of seats in parliament",
               "Population with at least some secondary education_Female",
               "Population with at least some secondary education_Male","Labour force participation rate_Female",
               "Labour force participation rate_Male"]

# %% [markdown]
# ### NaN values

# %%
#Checking for null values
df2.isnull().sum()
# Out:
# HDI_Rank_df2                                                7
# Country                                                     3
# Gender Inequality Index_Value_df2                           5
# Gender Inequality Index_Rank                                6
# Maternal mortality ratio                                    5
# Adolescent birth rate                                       5
# Share of seats in parliament                                5
# Population with at least some secondary education_Female    4
# Population with at least some secondary education_Male      6
# Labour force participation rate_Female                      4
# Labour force participation rate_Male                        6
# dtype: int64

# %%
df2 = df2.dropna()

# %% [markdown]
# ### Reset index

# %%
df2.reset_index(inplace = True, drop = True)

# %%
df2.head(10)
# Out:
#   HDI_Rank_df2                 Country Gender Inequality Index_Value_df2  \
# 0            1             Switzerland                             0.018
# 1            2                  Norway                             0.016
# 2            3                 Iceland                             0.043
# 3            4  Hong Kong, China (SAR)                                ..
# 4            5               Australia                             0.073
# 5            6                 Denmark                             0.013
# 6            7                  Sweden                             0.023
# 7            8                 Ireland                             0.074
# 8            9                 Germany                             0.073
# 9           10             Netherlands                             0.025
#
#   Gender Inequality Index_Rank Maternal mortality ratio Adolescent birth rate  \
# 0                            3                        5                 2.212
# ...

# %% [markdown]
# ## Importing DF3

# %%
df3 = pd.read_excel("C:\\Users\\Lenovo\\Downloads\\HDR21-22_Statistical_Annex_GDI_Table.xlsx")

# %%
df3.head()
# Out:
#        Back Table 4. Gender Development Index                Unnamed: 2  \
# 0       NaN                               NaN                       NaN
# 1       NaN                               NaN                       NaN
# 2       NaN                               NaN  Gender Development Index
# 3       NaN                               NaN                       NaN
# 4  HDI rank                           Country                     Value
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5               Unnamed: 6  Unnamed: 7  \
# 0         NaN        NaN        NaN                      NaN         NaN
# 1         NaN        NaN        NaN                      NaN         NaN
# 2         NaN        NaN        NaN  Human Development Index         NaN
# 3         NaN        NaN        NaN                    Value         NaN
# 4         NaN      Group          b                   Female         NaN
#
#   Unnamed: 8  Unnamed: 9  ... Unnamed: 16 Unnamed: 17  \
# ...

# %% [markdown]
# ### Dropping columns and rows

# %%
#Dropping blank columns
df3 = df3.drop(["Unnamed: 3","Unnamed: 5","Unnamed: 7","Unnamed: 9","Unnamed: 9","Unnamed: 11","Unnamed: 13","Unnamed: 15",
                "Unnamed: 17","Unnamed: 19","Unnamed: 21","Unnamed: 23","Unnamed: 25"],axis = 1)

# %%
#Dropping miscellaneous rows
df3=df3.drop(df3.index[[0,1,2,3,4,5,6]])

# %% [markdown]
# ### Column headers

# %%
# Adding column headers
df3.columns = ["HDI_Rank_df3","Country",'Gender Inequality Index_Value',"Gender Inequality Index_Group_df3",
               'Human Development_Female',"Human Development_Male","Life expectancy at birth_Female",
               "Life expectancy at birth_Male","Expected years of schooling_Female","Expected years of schooling_Male",
               "Mean years of schooling_Female","Mean years of schooling_Male",
               "Estimated gross national income per capita_Female","Estimated gross national income per capita_Male"]

# %% [markdown]
# ### Reset index

# %%
df3.reset_index(inplace = True, drop = True)

# %% [markdown]
# ### Nan Values

# %%
#Checking for null values
df3.isnull().sum()
# Out:
# HDI_Rank_df3                                         3
# Country                                              0
# Gender Inequality Index_Value                        3
# Gender Inequality Index_Group_df3                    3
# Human Development_Female                             3
# Human Development_Male                               3
# Life expectancy at birth_Female                      3
# Life expectancy at birth_Male                        3
# Expected years of schooling_Female                   3
# Expected years of schooling_Male                     3
# Mean years of schooling_Female                       3
# Mean years of schooling_Male                         3
# Estimated gross national income per capita_Female    3
# Estimated gross national income per capita_Male      3
# dtype: int64

# %%
df3 = df3.dropna()

# %%
df3.head(10)
# Out:
#   HDI_Rank_df3                 Country Gender Inequality Index_Value  \
# 0            1             Switzerland                         0.967
# 1            2                  Norway                         0.983
# 2            3                 Iceland                         0.976
# 3            4  Hong Kong, China (SAR)                         0.976
# 4            5               Australia                         0.968
# 5            6                 Denmark                          0.98
# 6            7                  Sweden                         0.988
# 7            8                 Ireland                         0.987
# 8            9                 Germany                         0.978
# 9           10             Netherlands                         0.968
#
#   Gender Inequality Index_Group_df3 Human Development_Female  \
# 0                                 2                 0.943709
# 1                                 1                   0.9499
# ...

# %% [markdown]
# ## Merging Datasets

# %%
a = df1.merge(df2,how='left', on=['Country'])

# %%
df = a.merge(df3,how = 'left', on = 'Country')

# %%
df.head()
# Out:
#   S.NO.                 Country    HDI Life expectancy  \
# 0     1             Switzerland  0.962         83.9872
# 1     2                  Norway  0.961         83.2339
# 2     3                 Iceland  0.959         82.6782
# 3     4  Hong Kong, China (SAR)  0.952         85.4734
# 4     5               Australia  0.951         84.5265
#
#   Expected years of schooling Mean years of schooling GNI per capita  \
# 0                   16.500299                13.85966    66933.00454
# 1                     18.1852                13.00363    64660.10622
# 2                   19.163059                13.76717    55782.04981
# 3                    17.27817                12.22621     62606.8454
# 4                    21.05459                12.72682    49238.43335
#
#   GNI rank minus HDI rank HDI rank_df1 Human_Development  ...  \
# 0                       5            3         Very High  ...
# 1                       6            1         Very High  ...
# ...

# %% [markdown]
# ### Displaying features

# %%
# Using tabulate to display features
def print_dataframe(df):
    print(tabulate(df))
print(tabulate(df,headers='keys'))
# Out:
#        S.NO.  Country                               HDI    Life expectancy    Expected years of schooling    Mean years of schooling    GNI per capita    GNI rank minus HDI rank    HDI rank_df1  Human_Development      HDI_Rank_df2  Gender Inequality Index_Value_df2    Gender Inequality Index_Rank    Maternal mortality ratio      Adolescent birth rate  Share of seats in parliament    Population with at least some secondary education_Female    Population with at least some secondary education_Male    Labour force participation rate_Female    Labour force participation rate_Male      HDI_Rank_df3  Gender Inequality Index_Value    Gender Inequality Index_Group_df3    Human Development_Female    Human Development_Male      Life expectancy at birth_Female    Life expectancy at birth_Male  Expected years of schooling_Female    Expected years of schooling_Male    Mean years of schooling_Female    Mean years of schooling_Male    Estimated gross national income per capita_Female    Estimated g
# ...

# %% [markdown]
# # `DATA CLEANING AND PRE PROCESSING`

# %%
df = df.reindex(columns=['S.NO.', 'Country','HDI', 'HDI rank_df1', 'HDI_Rank_df2','HDI_Rank_df3',
                                 'Life expectancy','Life expectancy at birth_Female','Life expectancy at birth_Male',
                                 'Expected years of schooling','Expected years of schooling_Female',
                                 'Expected years of schooling_Male','Mean years of schooling','Mean years of schooling_Female',
                                 'Mean years of schooling_Male','GNI per capita',
                                 'Estimated gross national income per capita_Female','Estimated gross national income per capita_Male',
                                 'Human_Development','Human Development_Female','Human Development_Male','Gender Inequality Index_Value',
                                 'Gender Inequality Index_Rank','Gender Inequality Index_Value_df2','Gender Inequality Index_Group_df3',
                                 'Maternal mortality ratio','Adolescent birth rate','Share of seats in parliament',
                                 'Population with at least some secondary education_Female','Population with at least some secondary education_Male',
                                 'Labour force participation rate_Female','Labour force participation rate_Male',
                                 'GNI rank minus HDI rank'])

# %% [markdown]
# ### Checking for duplicate columns

# %%
 
def getDuplicateColumns(df):
 
    # Create an empty set
    duplicateColumnNames = set()
 
    # Iterate through all the columns
    # of dataframe
    for x in range(df.shape[1]):
 
        # Take column at xth index.
        col = df.iloc[:, x]
 
        # Iterate through all the columns in
        # DataFrame from (x + 1)th index to
        # last index
        for y in range(x + 1, df.shape[1]):
 
            # Take column at yth index.
            otherCol = df.iloc[:, y]
 
            # Check if two columns at x & y
            # index are equal or not,
            # if equal then adding
            # to the set
            if col.equals(otherCol):
                duplicateColumnNames.add(df.columns.values[y])
 
    # Return list of unique column names
    # whose contents are duplicates.
    return list(duplicateColumnNames)

# %%
# Get list of duplicate columns
duplicateColNames = getDuplicateColumns(df)
 
for column in duplicateColNames:
    print('Column Name : ', column)
# Out:
# Column Name :  HDI_Rank_df2
# Column Name :  HDI_Rank_df3

# %%
#Dropping duplicate column

df = df.drop("HDI_Rank_df2",axis = 1)

# %% [markdown]
# ## Renaming and Cleaning the columns

# %%
df = df.drop(['S.NO.','HDI rank_df1','Gender Inequality Index_Value_df2',"HDI_Rank_df3"],axis=1)

# %%
#Storing the list of all initial column names in a list
initial_columns = list(df.columns)

# %%
# Storing the name of new column names in a list
new_columns = ['Country', 'HDI','Life_exp', 'Life_exp_F', 'Life_exp_M', 'Schooling', 'Schooling_F', 
               'Schooling_M', 'Mean_Schooling', 'Mean_Schooling_F', 'Mean_Schooling_M', 'GNI', 'GNI_F', 'GNI_M',
               'Human_Dev', 'Human_Dev_F', 'Human_Dev_M', 'GI_Value', 'GI_Rank', 'GI_Group', 'MMR', 'ABR', 'SSP',
               'Pop_F', 'Pop_M', 'Labor_F', 'Labor_M', 'GNI-HDI']

'''
HDI --> Human Development Index
GNI --> Gross National Income
GI --> Gender Inequality
MMR --> Maternal Mortality Ratio
ABR --> Adolescent Birth Rate
Pop_F --> Population_Female
SSP --> Share of seats in parliament

'''
# Out:
# '\nHDI --> Human Development Index\nGNI --> Gross National Income\nGI -->\xa0Gender Inequality\nMMR --> Maternal Mortality Ratio\nABR --> Adolescent Birth Rate\nPop_F --> Population_Female\nSSP --> Share of seats in parliament\n\n'

# %%
# User-Defined function for renaming function

def renameColumn(df, old_column, new_column):
    df.rename(columns = {old_column:new_column}, inplace = True)

# %%
for i in range(len(initial_columns)):
    renameColumn(df, initial_columns[i], new_columns[i])

# %%
df.head()
# Out:
#                   Country    HDI Life_exp Life_exp_F Life_exp_M  Schooling  \
# 0             Switzerland  0.962  83.9872    85.8959    81.9952  16.500299
# 1                  Norway  0.961  83.2339    84.8787    81.5622    18.1852
# 2                 Iceland  0.959  82.6782    84.1804    81.2138  19.163059
# 3  Hong Kong, China (SAR)  0.952  85.4734    88.3257    82.6613   17.27817
# 4               Australia  0.951  84.5265    85.8396    83.1718   21.05459
#
#   Schooling_F Schooling_M Mean_Schooling Mean_Schooling_F  ... GI_Rank  \
# 0    16.40519   16.593439       13.85966         13.48301  ...       3
# 1   18.886789    17.52533       13.00363         13.13508  ...       2
# 2    20.27153   18.090469       13.76717         13.86953  ...       8
# 3   17.572201   17.033239       12.22621          11.8457  ...      ..
# 4   21.817579    20.30188       12.72682         12.81059  ...      19
#
#   GI_Group MMR    ABR        SSP      Pop_F      Pop_M Labor_F Labor_M GNI-HDI
# ...

# %% [markdown]
# ## NaN Values

# %%
df.isnull().sum()
# Out:
# Country             0
# HDI                 0
# Life_exp            0
# Life_exp_F          0
# Life_exp_M          0
# Schooling           0
# Schooling_F         0
# Schooling_M         0
# Mean_Schooling      0
# Mean_Schooling_F    0
# Mean_Schooling_M    0
# GNI                 0
# GNI_F               0
# GNI_M               0
# Human_Dev           0
# Human_Dev_F         0
# Human_Dev_M         0
# GI_Value            0
# GI_Rank             0
# GI_Group            0
# MMR                 0
# ABR                 0
# SSP                 0
# Pop_F               0
# Pop_M               0
# Labor_F             0
# Labor_M             0
# GNI-HDI             0
# dtype: int64

# %%
# Replacing dot values with NaN
df = df.replace(to_replace="..", value=np.NaN)

# %%
# Checking for null values

df.isnull().sum()
# Out:
# Country              0
# HDI                  0
# Life_exp             0
# Life_exp_F           0
# Life_exp_M           0
# Schooling            0
# Schooling_F          4
# Schooling_M          4
# Mean_Schooling       0
# Mean_Schooling_F    12
# Mean_Schooling_M    12
# GNI                  0
# GNI_F               13
# GNI_M               13
# Human_Dev            0
# Human_Dev_F         19
# Human_Dev_M         19
# GI_Value            19
# GI_Rank             21
# GI_Group            19
# MMR                  9
# ABR                  0
# SSP                  2
# Pop_F               14
# Pop_M               14
# Labor_F             13
# Labor_M             13
# GNI-HDI              0
# dtype: int64

# %% [markdown]
# ### Reset index

# %%
df = df.dropna()
df.reset_index(drop = True, inplace = True)

# %% [markdown]
# ## Maximum and Minimum Values of columns

# %%
print("-"*40)

maxValues = df.max() 
print("Maximum values of each column:","\n",maxValues)

print("-"*40)

minValues = df.min()
print("Minimum values of each column:","\n",minValues)

print("-"*40)
# Out:
# ----------------------------------------
# Maximum values of each column:
#  Country                  Zimbabwe
# HDI                         0.962
# Life_exp                  84.7839
# Life_exp_F                87.7313
# Life_exp_M                83.1718
# Schooling                21.05459
# Schooling_F             21.817579
# Schooling_M              20.30188
# Mean_Schooling          14.090967
# Mean_Schooling_F        13.914979
# Mean_Schooling_M        14.349436
# GNI                   90918.64471
# GNI_F                75093.993862
# GNI_M               105348.328286
# Human_Dev               Very High
# Human_Dev_F                0.9499
# Human_Dev_M              0.975611
# GI_Value                    1.034
# GI_Rank                     170.0
# GI_Group                      5.0
# MMR                        1150.0
# ABR                       170.462
# SSP                     55.660377
# Pop_F                       100.0
# Pop_M                       100.0
# ...

# %% [markdown]
# ## Converting the data types of columns

# %% [markdown]
# ### Converting columns data type to float

# %%
column_to_num = ['HDI','Life_exp','Life_exp_F','Life_exp_M','Schooling','Schooling_F','Schooling_M','Mean_Schooling',
                 'Mean_Schooling_F','Mean_Schooling_M','GNI','GNI_F','GNI_M','Human_Dev_F','Human_Dev_M','GI_Value',
                 'ABR','SSP','Pop_F','Pop_M','Labor_F','Labor_M']

# %%
# coerce - It will replace all non-numeric values with NaN
for i in range(len(column_to_num)):
    df[column_to_num[i]] = pd.to_numeric(df[column_to_num[i]],errors='coerce')

# %% [markdown]
# ### Converting column data type to integer

# %%
col_to_int = ['GI_Rank', 'GI_Group', 'MMR', 'GNI-HDI']

# %%
for i in range(len(col_to_int)):
    df[col_to_int[i]] = df[col_to_int[i]].astype('int')

# %%
# Checking data types
df.dtypes
# Out:
# Country              object
# HDI                 float64
# Life_exp            float64
# Life_exp_F          float64
# Life_exp_M          float64
# Schooling           float64
# Schooling_F         float64
# Schooling_M         float64
# Mean_Schooling      float64
# Mean_Schooling_F    float64
# Mean_Schooling_M    float64
# GNI                 float64
# GNI_F               float64
# GNI_M               float64
# Human_Dev            object
# Human_Dev_F         float64
# Human_Dev_M         float64
# GI_Value            float64
# GI_Rank               int32
# GI_Group              int32
# MMR                   int32
# ABR                 float64
# SSP                 float64
# Pop_F               float64
# Pop_M               float64
# Labor_F             float64
# Labor_M             float64
# GNI-HDI               int32
# dtype: object

# %% [markdown]
# ### Final Dataset

# %%
df
# Out:
#                       Country    HDI  Life_exp  Life_exp_F  Life_exp_M  \
# 0                 Switzerland  0.962   83.9872     85.8959     81.9952
# 1                      Norway  0.961   83.2339     84.8787     81.5622
# 2                     Iceland  0.959   82.6782     84.1804     81.2138
# 3                   Australia  0.951   84.5265     85.8396     83.1718
# 4                     Denmark  0.948   81.3753     83.2762     79.4848
# ..                        ...    ...       ...         ...         ...
# 164                   Burundi  0.426   61.6627     63.6092     59.7112
# 165  Central African Republic  0.404   53.8947     56.3035     51.6455
# 166                     Niger  0.400   61.5763     62.7943     60.4065
# 167                      Chad  0.394   52.5254     54.2828     50.8449
# 168               South Sudan  0.385   54.9752     56.4723     53.4286
#
#      Schooling  Schooling_F  Schooling_M  Mean_Schooling  Mean_Schooling_F  \
# ...

# %%
df.to_csv("trial.csv", header=True, index=False)

# %% [markdown]
# # `DATA INTERPRETATION`
# ### Exploratory Data Analysis: Part 1

# %% [markdown]
# ***Categories of Human Development of countries***

# %%
df.groupby('Human_Dev').size().plot(kind='pie',shadow=True,startangle=90, autopct='%1.1f%%')

font1 = {'family':'serif','color':'black','size':20}
plt.title('HUMAN DEVELOPMENT',fontdict = font1)
# Out:
# Text(0.5, 1.0, 'HUMAN DEVELOPMENT')

# %% [markdown]
# Observation: The above pie chart represents the countries with categories of Human Development. There are four categories: Very High, High, Medium and Low. A lot of countries in the world have high human development followed by countries with High, Medium and Low Human Development.

# %% [markdown]
# ***Categories of Income groups of countries***

# %% [markdown]
# The World Bank assigns the world’s economies to four income groups—low, lower-middle, upper-middle, and high-income countries as follows:

# %%
High_Income = df[df["GNI"]>=12696]

# %%
plt.boxplot(High_Income.GNI)
font2 = {'family':'serif','color':'black','size':15}
plt.xlabel("High Income Countries",fontdict=font2)
plt.show()

# %% [markdown]
# Observation: The Gross National Income(GNI) of High Income countries are between 12696-45000. The mean income of the high income country is 30,000.

# %%
Low_Income = df[df["GNI"]<=1046]

# %%
import matplotlib.pyplot as plt
plt.boxplot(Low_Income.GNI)
plt.xlabel("Low Income Countries",fontdict=font2)
plt.show()

# %% [markdown]
# Observation: The Gross National Income(GNI) of Low Income countries are between 750-1046.The mean income of the Low income country is 770.

# %%
Lower_Middle = df[(df["GNI"]>=1045) & (df["GNI"]<=4095)]

# %%
import matplotlib.pyplot as plt
plt.boxplot(Lower_Middle.GNI)
plt.xlabel("Lower Middle Income Countries",fontdict=font2)
plt.show()

# %% [markdown]
# Observation: The Gross National Income(GNI) of Lower Middle countries are between 1600-3400. The mean income of the Lower Middle country is 2300.

# %%
Upper_Middle = df[(df["GNI"]>=4096) & (df["GNI"]<=12695)]

# %%
plt.boxplot(Upper_Middle.GNI)
plt.xlabel("Upper Middle Income Countries",fontdict=font2)
plt.show()

# %% [markdown]
# Observation: The Gross National Income(GNI) of Upper Middle countries are between 4096-10000.The mean income of the Upper Middle country is 8000.

# %%
#plotting
plt.plot(High_Income.GNI,color='Green')
plt.plot(Upper_Middle.GNI,color='Orange')
plt.plot(Lower_Middle.GNI,color='Yellow')
plt.plot(Low_Income.GNI,color='Red')

#setting the details
font1 = {'family':'serif','color':'black','size':20}
font2 = {'family':'serif','color':'black','size':15}

# giving X and Y labels
plt.xlabel("Countries", fontdict = font2)
plt.ylabel("Income", fontdict = font2)

#giving title
plt.title('Income Groups',fontdict = font1)

# visualizing the plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Observation: The above graph displays the income groups of the countries of the world.

# %% [markdown]
# ***Relationship between High Income Economies and Human Development Index***

# %%
len(df[df["GNI"]>=12696].HDI)
# Out:
# 82

# %%
len(High_Income['GNI'])
# Out:
# 82

# %%
fig, ax = plt.subplots(figsize=(20, 10))
bar = sns.barplot(x = High_Income['GNI'], y = df[df["GNI"]>=12696].HDI)
bar.tick_params(axis='x', rotation=90)

# %%
High_Income.nlargest(1, 'GNI').Country
# Out:
# 10    Singapore
# Name: Country, dtype: object

# %% [markdown]
# Observation: Among the High Income countries, Singapore has the highest HDI(Human Development Index). We can infer that Singapore has the best healthcare,knowledge and standard of living out of all the countries in th World. It is one of the highest income countries.

# %% [markdown]
# ***Relationship between Country and Gross National Income***

# %%
fig, ax = plt.subplots(figsize=(40, 10))
bar = sns.barplot(x = df['Country'], y = df['GNI'])
bar.tick_params(axis='x', rotation=90)

# %%
df.nlargest(5, 'GNI').Country
# Out:
# 10      Singapore
# 39          Qatar
# 14     Luxembourg
# 6         Ireland
# 0     Switzerland
# Name: Country, dtype: object

# %% [markdown]
# Observation: Singapore, Qatar, Luxembourg, Ireland and Switzerland are the top 5 countries having highest GNI. It means that these countries have better macro - economic indicators like Literacy Ratio, Heathcare, Education, Safe drinking water etc. and these are one of the best developed countries in the world.

# %% [markdown]
# ***Realtionship between Human Development Countries, Life expectancy, Gross national Income and Human Development Index***

# %%
fig, ax = plt.subplots(figsize=(10,5))
bar = sns.barplot(x = df['Human_Dev'], y = df["Life_exp"], ci = None)
bar.tick_params(axis='x', rotation=30)

# %% [markdown]
# Observation: The countries that are highly developed have better life expectancy rate followed by countries with High, Medium and Low development.

# %%
fig, ax = plt.subplots(figsize=(10, 5))
bar = sns.barplot(x = df['Human_Dev'] , y = High_Income['HDI'], ci = None)
bar.tick_params(axis='x', rotation=90)

# %% [markdown]
# Observation: The countries that are highly developed have better Human Developmet Index followed by countries with High, Medium and Low development.

# %%
fig, ax = plt.subplots(figsize=(10,5))
bar = sns.barplot(x = df['Human_Dev'] , y = High_Income['GNI'], ci = None)
bar.tick_params(axis='x', rotation=90)

# %% [markdown]
# Observation: As the life expectancy and HDI of Highly developed countries was the highest, their Gross National income is also the highest followed by countries with High, Medium and Low development.

# %%
plt.plot(df.GNI_M,color='black')
plt.plot(df.GNI_F,color='brown')

#giving title
plt.title('Gross National Income',fontdict = font1)
# Out:
# Text(0.5, 1.0, 'Gross National Income')

# %% [markdown]
# Observation: The Gross national income(GNI) of men is greater than the GNI of women. This has mainly happened due to lack of schooling and gender inequality.

# %% [markdown]
# ***CORRELATION HEATMAP***

# %%
fig, ax = plt.subplots(figsize=(15,15))
sns.heatmap(df.corr(), annot=True,linewidths=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ***Regression plots***

# %%
sns.regplot(data = df,x = 'MMR', y = 'Life_exp')
# Out:
# <AxesSubplot:xlabel='MMR', ylabel='Life_exp'>

# %% [markdown]
# Observation: There is a negative relationship between MMR(Maternal Mortality Ratio) and Life expectancy. The number of deaths due to pregnancy-related causes per 100,000 live births leads to decrease in life expectancy.

# %%
sns.regplot(data = df,x = 'Schooling', y = 'ABR')
# Out:
# <AxesSubplot:xlabel='Schooling', ylabel='ABR'>

# %% [markdown]
# Observation: There is a negative relationship between ABR(Adoslescent Birth Rate) and Schoolig. We can infer that as the education qualification increases, people realize the problems associated with increasing population and hence reduces the adolescent birth rate( women giving birth at the age of 15-19 years per 1,000 women in that age group). Hence, they might also wish to adopt 'One Child Policy'.

# %%
sns.regplot(data = df,x = 'Schooling', y = 'Life_exp')
# Out:
# <AxesSubplot:xlabel='Schooling', ylabel='Life_exp'>

# %% [markdown]
# Observation: There is a positive relationship between Schooling and Life expectancy. As the schooling years increase, people get knowledge about better way of living a healthy life and hence, life_exp increases.

# %%
sns.regplot(data = df,x = 'SSP', y = 'Life_exp')
# Out:
# <AxesSubplot:xlabel='SSP', ylabel='Life_exp'>

# %%
sns.histplot(df.Life_exp,kde=True,color='orange')
# Out:
# <AxesSubplot:xlabel='Life_exp', ylabel='Count'>

# %%
mean(df.Life_exp)
# Out:
# 71.29509822485207

# %% [markdown]
# Observation: The mean life expectancy of all the countries in the world is 71 years.

# %% [markdown]
# ### **INFERENCES**

# %% [markdown]
# * The mean life expectancy of all the countries in the world is 71 years.
# * There are four categories of Human Development.: Very High, High, Medium and Low. Most of countries in the world have high human development followed by countries with High, Medium and Low Human Development.
# * The Gross National Income(GNI) of High Income countries are between 12696-45000. The mean income of the high income country is 30,000.
# * The Gross National Income(GNI) of Low Income countries are between 750-1046.The mean income of the Low income country is 770.
# * The Gross National Income(GNI) of Lower Middle countries are between 1600-3400. The mean income of the Lower Middle country is 2300.
# * The Gross National Income(GNI) of Upper Middle countries are between 4096-10000.The mean income of the Upper Middle country is 8000.
# *  Among the High Income countries, Singapore has the highest HDI(Human Development Index). We can infer that Singapore has the best healthcare,knowledge and standard of living out of all the countries in th World. It is one of the highest income countries.
# * Singapore, Qatar, Luxembourg, Ireland and Switzerland are the top 5 countries having highest GNI. It means that these countries have better macro - economic indicators like Literacy Ratio, Heathcare, Education, Safe drinking water etc. and these are one of the best developed countries in the world.
# * The countries that are highly developed have better life expectancy rate followed by countries with High, Medium and Low development.
# * The countries that are highly developed have better Human Developmet Index followed by countries with High, Medium and Low development.
# * As the life expectancy and HDI of Highly developed countries was the highest, their Gross National income is also the highest followed by countries with High, Medium and Low development.
# * The Gross national income(GNI) of men is greater than the GNI of women. This has mainly happened due to lack of schooling and gender inequality.
# *  There is a negative relationship between MMR(Maternal Mortality Ratio) and Life expectancy. The number of deaths due to pregnancy-related causes per 100,000 live births leads to decrease in life expectancy.
# * There is a negative relationship between ABR(Adoslescent Birth Rate) and Schoolig. We can infer that as the education qualification increases, people realize the problems associated with increasing population and hence reduces the adolescent birth rate( women giving birth at the age of 15-19 years per 1,000 women in that age group). Hence, they might also wish to adopt 'One Child Policy'.
# * There is a positive relationship between Schooling and Life expectancy. As the schooling years increase, people get knowledge about better way of living a healthy life and hence, life_exp increases.

# %% [markdown]
# # `DATA MINING`
# ### Exploratory Data Analysis: Part 2

# %%
x=df.iloc[list(df['Life_exp'].nlargest(n=5).index)]

# %%
y=df[(df['Life_exp'] > df['Life_exp'].mean()-0.35) & (df['Life_exp'] < df['Life_exp'].mean()+0.35)]

# %%
z=df.iloc[list(df['Life_exp'].nsmallest(n=5).index)]

# %%
new_df = pd.DataFrame()
new_df = new_df.append(x)
new_df = new_df.append(y)
new_df = new_df.append(z)
new_df.reset_index(drop=True, inplace=True)
new_df
# Out:
#                      Country    HDI  Life_exp  Life_exp_F  Life_exp_M  \
# 0                      Japan  0.925   84.7839     87.7313     81.8018
# 1                  Australia  0.951   84.5265     85.8396     83.1718
# 2                Switzerland  0.962   83.9872     85.8959     81.9952
# 3                      Malta  0.918   83.7769     86.1085     81.4414
# 4        Korea (Republic of)  0.925   83.6978     86.7603     80.3864
# 5                    Ukraine  0.773   71.6240     76.7002     66.5312
# 6                      Tonga  0.745   70.9857     73.7190     68.4164
# 7                   Mongolia  0.739   70.9754     75.6958     66.5368
# 8                Saint Lucia  0.715   71.1114     74.7166     67.8378
# 9                 Tajikistan  0.685   71.5942     73.7339     69.5682
# 10                      Chad  0.394   52.5254     54.2828     50.8449
# 11                   Nigeria  0.535   52.6760     53.0701     52.2846
# ...

# %%
new_df_col = list(new_df.columns)
new_df_col.pop(0)
new_df_col.remove('Human_Dev')
new_df_col
# Out:
# ['HDI',
#  'Life_exp',
#  'Life_exp_F',
#  'Life_exp_M',
#  'Schooling',
#  'Schooling_F',
#  'Schooling_M',
#  'Mean_Schooling',
#  'Mean_Schooling_F',
#  'Mean_Schooling_M',
#  'GNI',
#  'GNI_F',
#  'GNI_M',
#  'Human_Dev_F',
#  'Human_Dev_M',
#  'GI_Value',
#  'GI_Rank',
#  'GI_Group',
#  'MMR',
#  'ABR',
#  'SSP',
#  'Pop_F',
#  'Pop_M',
#  'Labor_F',
#  'Labor_M',
#  'GNI-HDI']

# %%
for i in new_df_col:
    fig, ax = plt.subplots(figsize=(40, 10))
    bar = sns.barplot(data = new_df, x = 'Country', y = i)
    bar.tick_params(axis='x', rotation=90)
    plt.title(("Country vs " + i), fontsize = 40)
# Out:
# <ipython-input-88-a1eeb7b910d9>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=(40, 10))

# %% [markdown]
# ### **INFERENCES** <br>
# The new df is arranged according to top 5 countries that have highest life expectancy,bottom 5 countries that have lowest life expectancy and 5 countries that have average life expectancy. The following inferences can be made: <br>
# 1. **HDI** <br>
# a.The HDI(Human Development Index) of countries with high life expectancy is greater. <br>
# b.Switzerland has the highest HDI and Chad has the lowest HDI. <br>
#
# 2. **Life expectancy** <br>
# a.There is not much difference between the life expectancy of males and females.<br>
# b.Australia has the highest number of schooling years that displays that they have ustilized resources for education. Greater the education, Greater the Human development index and hence, Greater the life expectancy. <br>
# c.Chad has the lowest life expectancy. <br>
#
# 3. **Schooling** <br>
# a.There is not much difference between the Schooling of males and females. <br>
# b.Australia has the highest Schooling and South Sudan has the lowest Schooling. <br>
#
# 4. **Gross National income** <br>
# a.The Gross National income of Switzerland is the highest and South Sudan has the lowest GNI. <br>
# b.There is not much difference between the Gross national income of males and females. <br>
#
# 5. **Human Development** <br>
# a.Switzerland has the highest Human devlopment and Chad has the lowest Human development. <br>
#
# 6. **Gender Inequality Index** <br>
# a.The Gender Inequality Rank of countries with low life expectancy is greater.This shows that gender inequality affects life expectancy. <br>
# b.Switzerland has the lowest GI and Central African Republic has the highest GI. <br>
#
# 7. **Maternal Mortality Ratio** <br>
# a.Maternal Mortality Ratio of countries with low life expectancy is greater while that of higher life expectancy is negligible. <br>
# b. Australia, Japan, Switzerland, Malta has the lowest MMR and Chad,South Sudan has the highest MMR. <br>
#
# 8. **Adolescent Birth Rate** <br>
# a.Adolescent Birth Rate of countries with low life expectancy is greater while that of higher life expectancy is negligible. <br>
# b.Japan, Switzerland,Korea have lowest ABR and Central African republic has the highest ABR. <br>
#
# 9. **Share of seats in parliament** <br>
# a.The share of seats in parliament of a country called Tonga is 0. <br>
# b.There is not much correlation between the life expectancy and share of seats in parliament. <br>
# c.Switzerland has the highest share of seats in parliament and Nigeria has the lowest.<br>
#
# 10. **Population** <br>
# a.Australia, Ukraine has the highest population and Chad has the lowest.<br>
#
# 11. **Labor Force** <br>
# a. Labor force of males is greater than Labor force of females. <br>
# b. Central African republic has the highest Labor Force and Tajikistan has the lowest.<br>

# %% [markdown]
# # `DATA TRANSFORMATION`

# %%
country_le = LabelEncoder()
df['Country'] = country_le.fit_transform(df['Country'])

# %%
human_dev_le = LabelEncoder()
df['Human_Dev'] = human_dev_le.fit_transform(df['Human_Dev'])

# %% [markdown]
# # `MODEL TESTING`

# %% [markdown]
# ### LINEAR REGRESSION

# %% [markdown]
# #### SplIt the data into TRAIN and TEST

# %% [markdown]
# Correlation coefficients whose magnitude are between 0.5 and 0.7 indicate variables are considered moderately correlated. Therefore, we consider variables which are moderately and highly correlated.

# %%
#pop - removes an item at the specified index from the list. 
corr_matrix=df.corr()
features=[]

for feature,value in corr_matrix['Life_exp'].iteritems():
    if abs(value) > 0.5:
        features.append(feature)
    else:
        pass

# %%
features.pop(1)
# Out:
# 'Life_exp'

# %%
features.pop(1)
# Out:
# 'Life_exp_F'

# %%
features.pop(1)
# Out:
# 'Life_exp_M'

# %%
features.append('Country')

# %%
X = df[features]
y = df['Life_exp']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 69)

# %%
# Defining the Model
lr = LinearRegression()

# %%
# Fitting the Model
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
sns.regplot(y_test, y_pred)
plt.xlabel("True Life Expectancy")
plt.ylabel("Predicted Life Expectancy")
plt.title('MODEL ACCURACY')
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Evaluation Metrics
print("Accuracy = {}".format(r2_score(y_test, y_pred)))
# Out:
# Accuracy = 0.940800043937502

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 3.787861370773202

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 1.493989993039218

# %%
lr.coef_
# Out:
# array([-1.23778080e+01, -1.23639927e+00,  1.42603575e+00, -8.30457879e-01,
#        -3.58077391e+00,  1.91324610e+00,  5.96285064e-01, -6.59935843e-05,
#         1.81878781e-04, -9.25450443e-05, -5.26296770e+00,  9.09045267e+01,
#        -4.12863217e-02,  7.03617809e-01, -4.15443098e-03,  2.62103541e-03,
#        -1.78172948e-02, -1.56215158e-02,  2.17790350e-03])

# %%
lr.intercept_
# Out:
# 40.69393133854828

# %% [markdown]
# ### Predicting Life Expectancy from User-Input

# %%
def predictLE(regressor, values):
    equation = 0
    intercept = regressor.intercept_
    weights = regressor.coef_
    
    for i in range(len(values)):
        equation += weights[i]*values[i]
    equation += intercept
    
    print("The life expectancy is: ", equation)

# %%
print('-'*30)
country = input("Enter the Country Name: ")
hdi = float(input("Enter the Human Developmet Index: "))
schooling = float(input("Enter the Schooling: "))
schooling_f = float(input("Enter the Female Schooling: "))
schooling_m = float(input("Enter the Male Schooling: "))
mean_schooling = float(input("Enter the Mean Schooling: "))
mean_schooling_f = float(input("Enter the Mean of Male Schooling: "))
mean_schooling_m = float(input("Enter the Mean of Female Schooling: "))
gni = float(input("Enter the Gross National Income: "))
gni_f = float(input("Enter the Gross National Income of Females: "))
gni_m = float(input("Enter the Gross National Income of Males: "))
human_Dev_F = float(input("Enter the Human development of Females: "))
human_Dev_M = float(input("Enter the Human development of Males: "))
gi_Rank = float(input("Enter the Gender Inequality Rank: "))
gi_Group = float(input("Enter the Gender Inequality Group: "))
mmr = float(input("Enter the Maternal Mortality Ratio: "))
abr = float(input("Enter the Adolescent Birth Rate: "))
pop_f = float(input("Enter the Male population: "))
pop_m = float(input("Enter the Female population: "))
print('-'*30, "\n")

country_label = country_le.transform([country])
country_label = country_label[0]
values = [hdi,schooling,schooling_f,schooling_m,mean_schooling,mean_schooling_f,mean_schooling_m,gni,gni_f,gni_m,human_Dev_F,
           human_Dev_M,gi_Rank,gi_Group,mmr,abr,pop_f,pop_m,country_label]

predictLE(lr, values)
# Out:
# ------------------------------
# Enter the Country Name: Japan
# Enter the Human Developmet Index: 0.92
# Enter the Schooling: 15.2
# Enter the Female Schooling: 15.1
# Enter the Male Schooling: 15.2
# Enter the Mean Schooling: 13.3
# Enter the Mean of Male Schooling: 13.3
# Enter the Mean of Female Schooling: 13.4
# Enter the Gross National Income: 42274
# Enter the Gross National Income of Females: 30620
# Enter the Gross National Income of Males: 54596
# Enter the Human development of Females: 0.90
# Enter the Human development of Males: 0.93
# Enter the Gender Inequality Rank: 33
# Enter the Gender Inequality Group: 2
# Enter the Maternal Mortality Ratio: 5
# Enter the Adolescent Birth Rate: 2.9
# Enter the Male population: 95.8
# Enter the Female population: 92.7
# ------------------------------
#
# The life expectancy is:  79.80657144217278

# %% [markdown]
# <hr>
