# %% [markdown]
# # Python Lab 4 - Exploring Plotting
#
# **Name: Sneha Gupta <br>
# RegNo: 21112341 <br>
# Class: 3BScEA**
# <hr>

# %% [markdown]
# **Obective** <br>
# Import the Titanic Dataset and perform the following. You may rework on the last class activity's code for easier processing.
# * At least three plots using Pandas Plot
# * At least four plots using Matplotlib
# * At least five plots using Seaborn

# %% [markdown]
# **Problem Definition** <br>
# * Importing Titanic dataset
# * Exploring different plots
# * Exploring different libraries - Pandas, Matplotlib, Seaborn

# %% [markdown]
# **Methodology**
# * Using pandas to extract dataframe
# * Using different libraries
# * Using plots like catplot, barplots, violinplots, scatterplots, pairplots

# %% [markdown]
# **Observations**
# * Seaborn library shows better plots than other libraries

# %% [markdown]
# **Result**
# * The majority of the people travelling in titanic were between the range of 20-30.
# * The highest fare was around 700 for the people of age group in the range 30-40 while most of the people had fare between 0-100.

# %% [markdown]
# **Learnings**
# * This assignment hepled me to understand and implement different plots using different libraries.

# %% [markdown]
# | Question Number | Status |
# | --- | --- |
# | 1 | Completed |
# | 2 | Completed |
# | 3 | Completed |

# %% [markdown]
# **References**
# * https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html
# * https://www.geeksforgeeks.org/python-titanic-data-eda-using-seaborn/

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\Lenovo\\Downloads\\titanic.csv")
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# ...

# %% [markdown]
# ## Pandas

# %%
df["Age"].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Observation - The majority of the people travelling in titanic were between the range of 20-30.

# %%
import pandas as pd
df.plot(kind = 'scatter', x = 'Age', y = 'Fare')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %% [markdown]
# Observation - The highest fare was around 700 for the people of age group in the range 30-40 while most of the people had fare between 0-100.

# %%
df.Survived.value_counts().plot(kind="bar",alpha=0.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observation - This plot shows the people survived

# %% [markdown]
# <hr>

# %% [markdown]
# ## Matplotlib

# %%
import matplotlib.pyplot as plt
df['Pclass'].plot(kind = 'hist')
plt.show()

# %% [markdown]
# Observation - It shows the pclass using histogram

# %%
import matplotlib.pyplot as plt
df.plot(x="Survived", y=("Fare"),kind="bar")
# print bar graph
plt.show()

# %% [markdown]
# Observation - It shows the fare an dthe survived

# %%
plt.boxplot(df.Age)
plt.show()

# %% [markdown]
# Observation - It shows the age of people using boxplot

# %%
df.plot(kind='bar',x='Age',y='Survived', color='red')
plt.show()

# %% [markdown]
# Observation - It shows the people survived

# %% [markdown]
# <hr>

# %% [markdown]
# ## Seaborn

# %%
import seaborn as sns

# %%
sns.catplot(x ="Sex", hue ="Survived",
kind ="count", data = df)

# %% [markdown]
# Observation - It shows the number of male and females survied using catplot

# %%
sns.stripplot(x='Sex', y='Age', data=df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %% [markdown]
# Observation - It shows the number of male and female along with their age using strip plot

# %%
sns.boxplot(x='Sex', y='Age', data=df, hue="Survived")
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %% [markdown]
# Observation - It shows the number of males and females survived using boxplot

# %%
sns.violinplot(x='Sex', y='Age', data=df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %% [markdown]
# Observation - It shows the age of the male and females present using violinplot

# %%
sns.pairplot(df, hue='Sex')

# %% [markdown]
# Observation - It shows the pairplot of the full dataset

# %% [markdown]
# <hr>
